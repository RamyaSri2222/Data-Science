# %% [markdown]
# <a href="https://colab.research.google.com/github/RamyaSri2222/Data-Science/blob/main/adding_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-0159dc76-f940-41b9-821a-137461ea0207" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0159dc76-f940-41b9-821a-137461ea0207">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("sales8.csv")
df.loc[1,"Customer name"]="Ramya"
print(df)
# Out:
#     Order Id Customer name  Customer Id                Product name  \
# 0     192837         Veeru            3                   LG Mobile
# 1     192838         Ramya           19        Apple iPad 10.2-inch
# 2     192839        Balaji           12      34in Ultrawide Monitor
# 3     192840        Shahid           20                   iPhone 11
# 4     192841         Vinay           10  Bose SoundSport Headphones
# 5     192842         Vinay           10                20in Monitor
# 6     192843        Balaji           12                    iPhone 8
# 7     192844    Nireekshan            1      27in 4K Gaming Monitor
# 8     192845          Venu           23                    iPhone 9
# 9     192846         Veeru            3                20in Monitor
# 10    192847     Madhurima            7               Flatscreen TV
# 11    192848         Kedar            2               Flatscreen TV
# 12    192849          Venu           23          Samsung Galaxy S20
# ...

# %%
import pandas as pd
df=pd.read_csv("sales8.csv")
m=df.drop(3,axis=0)
print(m.head())
# Out:
#    Order Id Customer name  Customer Id                Product name  \
# 0    192837         Veeru            3                   LG Mobile
# 1    192838       Neelima           19        Apple iPad 10.2-inch
# 2    192839        Balaji           12      34in Ultrawide Monitor
# 4    192841         Vinay           10  Bose SoundSport Headphones
# 5    192842         Vinay           10                20in Monitor
#
#    Product cost  Quantity
# 0         65999         1
# 1         63000         2
# 2         75999         1
# 4         69999         3
# 5         65999         2
