# %% [markdown]
# <a href="https://colab.research.google.com/github/RamyaSri2222/Data-Science/blob/main/polynomialFeature.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import asarray
from sklearn.preprocessing import PolynomialFeatures
data=asarray([[2],[3],[4]])
tarn=PolynomialFeatures(degree=1)
m=tarn.fit_transform(data)
print(m)
# Out:
# [[1. 2.]
#  [1. 3.]
#  [1. 4.]]

# %%
from numpy import asarray
from sklearn.preprocessing import PolynomialFeatures
data=asarray([[2],[3],[4]])
tarn=PolynomialFeatures(degree=2)
m=tarn.fit_transform(data)
print(m)
# Out:
# [[ 1.  2.  4.]
#  [ 1.  3.  9.]
#  [ 1.  4. 16.]]

# %%
from numpy import asarray
from sklearn.preprocessing import PolynomialFeatures
data=asarray([[1,2,],[3,4],[5,6]])
tran=PolynomialFeatures(degree=2)
data2=tarn.fit_transform(data)
print(data2)
# Out:
# [[ 1.  1.  2.  1.  2.  4.]
#  [ 1.  3.  4.  9. 12. 16.]
#  [ 1.  5.  6. 25. 30. 36.]]

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-176fbcf1-5064-481b-8b26-49ce5d746102" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-176fbcf1-5064-481b-8b26-49ce5d746102">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
df=pd.read_csv("poly_dataset.csv")
print(df)
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
df=pd.read_csv("poly_dataset.csv")
x=df.iloc[:,1:2].values
y=df.iloc[:,2].values
reg=LinearRegression()
reg.fit(x,y)
plt.scatter(x,y,color="chocolate",marker="*")
plt.plot(x,reg.predict(x),color="pink")
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
df=pd.read_csv("poly_dataset.csv")
x=df.iloc[:,1:2].values
y=df.iloc[:,2].values
tran=PolynomialFeatures(degree=2)
data=tran.fit_transform(x)
print(data)
# Out:
# [[  1.   1.   1.]
#  [  1.   2.   4.]
#  [  1.   3.   9.]
#  [  1.   4.  16.]
#  [  1.   5.  25.]
#  [  1.   6.  36.]
#  [  1.   7.  49.]
#  [  1.   8.  64.]
#  [  1.   9.  81.]
#  [  1.  10. 100.]]

# %%
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
df=pd.read_csv("poly_dataset.csv")
x=df.iloc[:,1:2].values
y=df.iloc[:,2].values
tran=PolynomialFeatures(degree=2)
data=tran.fit_transform(x)
reg=LinearRegression()
reg.fit(data,y)
print("Fitting the Ploynomial regression to the dataset")
# Out:
# Fitting the Ploynomial regression to the dataset

# %%
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
df=pd.read_csv("poly_dataset.csv")
x=df.iloc[:,1:2].values
y=df.iloc[:,2].values
tran=PolynomialFeatures(degree=2)
data=tran.fit_transform(x)
reg=LinearRegression()
reg.fit(data,y)
plt.scatter(x,y,color="blue",marker=".")
plt.plot(x,reg.predict(data),color="pink")
plt.title("Positional Regression")
plt.xlabel("positional level")
plt.ylabel("salary")
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
df=pd.read_csv("poly_dataset.csv")
x=df.iloc[:,1:2].values
y=df.iloc[:,2].values
tran=PolynomialFeatures(degree=3)
data=tran.fit_transform(x)
reg=LinearRegression()
reg.fit(data,y)
plt.scatter(x,y,color="blue",marker=".")
plt.plot(x,reg.predict(data),color="pink")
plt.title("Positional Regression")
plt.xlabel("positional level")
plt.ylabel("salary")
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
df=pd.read_csv("poly_dataset.csv")
x=df.iloc[:,1:2].values
y=df.iloc[:,2].values
tran=PolynomialFeatures(degree=4)
data=tran.fit_transform(x)
reg=LinearRegression()
reg.fit(data,y)
plt.scatter(x,y,color="blue",marker=".")
plt.plot(x,reg.predict(data),color="pink")
plt.title("Positional Regression")
plt.xlabel("positional level")
plt.ylabel("salary")
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
df=pd.read_csv("poly_dataset.csv")
x=df.iloc[:,1:2].values
y=df.iloc[:,2].values
tran=PolynomialFeatures(degree=4)
data=tran.fit_transform(x)
reg=LinearRegression()
reg.fit(data,y)
m=reg.predict(tran.fit_transform([[6.5]]))
print(m)
# Out:
# [158862.45265155]
